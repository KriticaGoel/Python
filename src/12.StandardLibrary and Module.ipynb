# %% [markdown]
# To create a module create __init__.py file inside package and the create a file (math) having all functions.
#
# from package.subpackage.math import *

# %% [markdown]
# #### Standard Library
# 1. math
# 2. random
# 3. csv
# 4. from datetime import datetime,timedelta
# 5. time -> only time -> it have sleep function
# 6. os
# 7. JSON -> convert string to dic and vicecersa. used for nosql
# 8. re -> Regular experssion

# %%
import random

print(random.randint(1,10))

print (random.choice(['Banana','Apple','Grapes']))
# Out:
# 6
# Banana

# %%
import json

# %%
data ={"Name" : "Kritica", "Age":35}
#1. Convert dictionary into string
json_dump = json.dumps(data)
print(type(json_dump))
print(json_dump)
# Out:
# <class 'str'>
# {"Name": "Kritica", "Age": 35}

# %%
# convert String to dictionary
json_dic=json.loads(json_dump)
print(json_dic)
print(type(json_dic))
# Out:
# {'Name': 'Kritica', 'Age': 35}
# <class 'dict'>

# %%
import re

text="Hello my name is Keritica my password is sadas123432"

pattern=r"\d+"

match=re.search(pattern,text)
print(match.group())
# Out:
# 123432
