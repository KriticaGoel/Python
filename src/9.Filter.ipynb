# %%
price_list=[100,250,400,1200,50,2000,850]
print(list(filter( lambda price : price>500 , price_list)))
print (list(filter( lambda price: price<=500,price_list)))
